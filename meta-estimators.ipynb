# %%
import numpy as np
import matplotlib.pylab as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples = 2000, n_features=2,
                          n_redundant=0, random_state=21,
                          class_sep=1.75, flip_y=0.1)
plt.scatter(X[:, 0], X[:, 1], c=y, s=5);

# %%
def make_plots():
    X_new = np.concatenate([
        np.random.uniform(np.min(X[:, 0]), np.max(X[:, 0]), (20000, 1)),
        np.random.uniform(np.min(X[:, 1]), np.max(X[:, 1]), (20000, 1))
    ], axis=1)
    plt.figure(figsize=(16, 4))
    plt.subplot(141)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=5)
    plt.title("original data")
    plt.subplot(142)
    plt.scatter(X_new[:, 0], X_new[:, 1], c=clf1.predict_proba(X_new)[:, 1], s=5)
    plt.title("ens1")
    plt.subplot(143)
    plt.scatter(X_new[:, 0], X_new[:, 1], c=clf2.predict_proba(X_new)[:, 1], s=5)
    plt.title("ens2")
    plt.subplot(144)
    plt.scatter(X_new[:, 0], X_new[:, 1], c=clf3.predict_proba(X_new)[:, 1], s=5)
    plt.title("ens3");

# %%
clf1 = LogisticRegression().fit(X, y)
clf2 = KNeighborsClassifier(n_neighbors=10).fit(X, y)
clf3 = VotingClassifier(estimators=[('clf1', clf1), ('clf2', clf2)],
                       voting='soft',
                       weights=[0.5, 0.5])

clf3.fit(X, y)

make_plots()

# %%
pip install sklego
# Out:
# Requirement already satisfied: sklego in c:\users\danielobare\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-lego in c:\users\danielobare\anaconda3\lib\site-packages (from sklego) (0.6.14)
# Requirement already satisfied: umap-learn>=0.4.6 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego->sklego) (0.5.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego->sklego) (0.5.3)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego->sklego) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.24.1 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego->sklego) (1.3.0)
# Requirement already satisfied: autograd>=1.2 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego->sklego) (1.6.2)
# Requirement already satisfied: Deprecated>=1.2.6 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego->sklego) (1.2.14)
# Requirement already satisfied: future>=0.15.2 in c:\users\danielobare\anaconda3\lib\site-packages (from autograd>=1.2->scikit-lego->sklego) (0.18.3)
# Requirement already satisfied: numpy>=1.12 in c:\users\danielobare\anaconda3\lib\site-packages (from autograd>=1.2->scikit-lego->sklego) (1.23.5)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\danielobare\anaconda3\lib\site-packages (from Deprecated>=1.2.6->scikit-lego->sklego) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\danielobare\appdata\roaming\python\python310\site-packages (from pandas>=1.1.5->scikit-lego->sklego) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danielobare\anaconda3\lib\site-packages (from pandas>=1.1.5->scikit-lego->sklego) (2022.7)
# Requirement already satisfied: six in c:\users\danielobare\appdata\roaming\python\python310\site-packages (from patsy>=0.5.1->scikit-lego->sklego) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-learn>=0.24.1->scikit-lego->sklego) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-learn>=0.24.1->scikit-lego->sklego) (2.2.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-learn>=0.24.1->scikit-lego->sklego) (1.10.0)
# Requirement already satisfied: tqdm in c:\users\danielobare\anaconda3\lib\site-packages (from umap-learn>=0.4.6->scikit-lego->sklego) (4.64.1)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\danielobare\anaconda3\lib\site-packages (from umap-learn>=0.4.6->scikit-lego->sklego) (0.5.10)
# Requirement already satisfied: numba>=0.49 in c:\users\danielobare\anaconda3\lib\site-packages (from umap-learn>=0.4.6->scikit-lego->sklego) (0.56.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\danielobare\anaconda3\lib\site-packages (from numba>=0.49->umap-learn>=0.4.6->scikit-lego->sklego) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\danielobare\anaconda3\lib\site-packages (from numba>=0.49->umap-learn>=0.4.6->scikit-lego->sklego) (65.6.3)
# Requirement already satisfied: colorama in c:\users\danielobare\appdata\roaming\python\python310\site-packages (from tqdm->umap-learn>=0.4.6->scikit-lego->sklego) (0.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-lego
# Out:
# Requirement already satisfied: scikit-lego in c:\users\danielobare\anaconda3\lib\site-packages (0.6.14)
# Requirement already satisfied: umap-learn>=0.4.6 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego) (0.5.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego) (0.5.3)
# Requirement already satisfied: Deprecated>=1.2.6 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego) (1.2.14)
# Requirement already satisfied: scikit-learn>=0.24.1 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego) (1.3.0)
# Requirement already satisfied: autograd>=1.2 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego) (1.6.2)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-lego) (1.5.3)
# Requirement already satisfied: numpy>=1.12 in c:\users\danielobare\anaconda3\lib\site-packages (from autograd>=1.2->scikit-lego) (1.23.5)
# Requirement already satisfied: future>=0.15.2 in c:\users\danielobare\anaconda3\lib\site-packages (from autograd>=1.2->scikit-lego) (0.18.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\danielobare\anaconda3\lib\site-packages (from Deprecated>=1.2.6->scikit-lego) (1.14.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danielobare\anaconda3\lib\site-packages (from pandas>=1.1.5->scikit-lego) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\danielobare\appdata\roaming\python\python310\site-packages (from pandas>=1.1.5->scikit-lego) (2.8.2)
# Requirement already satisfied: six in c:\users\danielobare\appdata\roaming\python\python310\site-packages (from patsy>=0.5.1->scikit-lego) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-learn>=0.24.1->scikit-lego) (2.2.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-learn>=0.24.1->scikit-lego) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\danielobare\anaconda3\lib\site-packages (from scikit-learn>=0.24.1->scikit-lego) (1.1.1)
# Requirement already satisfied: numba>=0.49 in c:\users\danielobare\anaconda3\lib\site-packages (from umap-learn>=0.4.6->scikit-lego) (0.56.4)
# Requirement already satisfied: tqdm in c:\users\danielobare\anaconda3\lib\site-packages (from umap-learn>=0.4.6->scikit-lego) (4.64.1)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\danielobare\anaconda3\lib\site-packages (from umap-learn>=0.4.6->scikit-lego) (0.5.10)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\danielobare\anaconda3\lib\site-packages (from numba>=0.49->umap-learn>=0.4.6->scikit-lego) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\danielobare\anaconda3\lib\site-packages (from numba>=0.49->umap-learn>=0.4.6->scikit-lego) (65.6.3)
# Requirement already satisfied: colorama in c:\users\danielobare\appdata\roaming\python\python310\site-packages (from tqdm->umap-learn>=0.4.6->scikit-lego) (0.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

from sklearn.pipeline import Pipeline
from sklearn.datasets import make_blobs
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, accuracy_score, make_scorer

from sklego.meta import Thresholder

# %%
X, y = make_blobs(1000, centers=[(0, 0), (1.5, 1.5)], cluster_std=[1, 0.5])
plt.scatter(X[:, 0], X[:, 1], c=y, s=5);

# %%
m1 = Thresholder(LogisticRegression(solver = 'lbfgs'), threshold = 0.1).fit(X, y)
m2 = Thresholder(LogisticRegression(solver = 'lbfgs'), threshold = 0.9).fit(X, y)

plt.figure(figsize=(12, 4))
plt.subplot(131)
plt.scatter(X[:, 0], X[:, 1], c=y, s=5)
plt.title("original data")
plt.subplot(132)
plt.scatter(X[:, 0], X[:, 1], c=m1.predict(X), s=5)
plt.title("threshold=0.1")
plt.subplot(133)
plt.scatter(X[:, 0], X[:, 1], c=m2.predict(X), s=5)
plt.title("threshold=0.9");

# %%
pipe = Pipeline([
    ("model", Thresholder(LogisticRegression(solver='lbfgs'), threshold=0.1))
])

mod = GridSearchCV(estimator=pipe,
                  param_grid={"model__threshold": np.linspace(0.1, 0.9, 50)},
                  scoring = {"precision": make_scorer(precision_score),
                            "recall": make_scorer(recall_score),
                            "accuracy": make_scorer(accuracy_score)},
                  refit = "precision",
                  cv = 5)

mod.fit(X, y);

# %%
# Extract the threshold values and performance metrics
thresholds = mod.cv_results_["param_model__threshold"]
precision_scores = mod.cv_results_["mean_test_precision"]
recall_scores = mod.cv_results_["mean_test_recall"]
accuracy_scores = mod.cv_results_["mean_test_accuracy"]

# Plot the scores against the threshold values
plt.figure(figsize=(12, 4))
plt.plot(thresholds, precision_scores, label="Precision")
plt.plot(thresholds, recall_scores, label="Recall")
plt.plot(thresholds, accuracy_scores, label="Accuracy")
plt.xlabel("Threshold")
plt.ylabel("Score")
plt.title("Model Performance vs. Threshold as done by Daniel Obare Nyakundi")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from sklego.datasets import load_chicken
from sklego.preprocessing import ColumnSelector

df = load_chicken(as_frame=True)

def plot_model(model):
    df = load_chicken(as_frame=True)
    model.fit(df[['diet', 'time']], df['weight'])
    metric_df = df[['diet', 'time', 'weight']].assign(pred=lambda d: model.predict(d[['diet', 'time']]))
    metric = mean_absolute_error(metric_df['weight'], metric_df['pred'])
    plt.figure(figsize=(12, 4))
    # plt.scatter(df['time'], df['weight'])
    for i in [1, 2, 3, 4]:
        pltr = metric_df[['time', 'diet', 'pred']].drop_duplicates().loc[lambda d: d['diet'] == i]
        plt.plot(pltr['time'], pltr['pred'], color='.rbgy'[i])
    plt.title(f"linear model per group, MAE: {np.round(metric, 2)}");

# %%
feature_pipeline = Pipeline([
    ("datagrab", FeatureUnion([
        ("discrete", Pipeline([
            ("grab", ColumnSelector("diet")),
            ("encode", OneHotEncoder(categories="auto", sparse_output=False))
        ])),
        ("continuous", Pipeline([
            ("grab", ColumnSelector('time')),
            ("standardize", StandardScaler())
        ]))
    ]))
])

pipe = Pipeline([
    ("transform", feature_pipeline),
    ("model", LinearRegression())
])

plot_model(pipe)

# %%
from sklego.meta import GroupedPredictor
mod = GroupedPredictor(LinearRegression(), groups=["diet"])
plot_model(mod)

# %%
#Time Series

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.model_selection import cross_val_score
from sklego.meta import ZeroInflatedRegressor

# Note the final line of code in this block. We're setting y=0 for all weekend dates
# while we simulate standard regression data for all the other dates.
df = (pd.DataFrame({'dt': pd.date_range("2018-01-01", "2021-01-01")})
      .assign(x=lambda d: np.random.normal(0, 1, d.shape[0]))
      .assign(weekend = lambda d: (d['dt'].dt.weekday >= 5).astype(np.int16))
      .assign(y=lambda d: np.where(d['weekend'], 0, 1.5 + 0.87 * d['x'] + np.random.normal(0, 0.2, d.shape[0]))))

# %%
X, y = df[['x', 'weekend']].values, df['y'].values

# %%
#Not sure abt this

# %%
zir = ZeroInflatedRegressor(
    classifier=LogisticRegression(),
    regressor=Ridge()
)

lr = Ridge(random_state=0)

print('ZIR r²:', cross_val_score(zir, X, y).mean())
print(' LR r²:', cross_val_score(lr, X, y).mean())
# Out:
# ZIR r²: 0.972421390900817
#  LR r²: 0.8335394453251121

# %%
from sklego.meta import GroupedPredictor, DecayEstimator
from sklego.datasets import make_simpleseries
from sklearn.dummy import DummyRegressor

yt = make_simpleseries(seed=1)
dates = pd.date_range("2000-01-01", periods=len(yt))
df = (pd.DataFrame({"yt": yt,
                   "date": dates})
     .assign(m=lambda d: d.date.dt.month)
     .reset_index())

plt.figure(figsize=(12, 3))
plt.plot(dates, make_simpleseries(seed=1));

# %%
mod1 = (GroupedPredictor(DummyRegressor(), groups=["m"])
       .fit(df[['m']], df['yt']))

plt.figure(figsize=(12, 3))
plt.plot(df['yt'], alpha=0.5);
plt.plot(mod1.predict(df[['m']]), label="grouped")
plt.legend();

# %%
mod1 = (GroupedPredictor(DummyRegressor(), groups=["m"])
       .fit(df[['m']], df['yt']))

mod2 = (GroupedPredictor(DecayEstimator(DummyRegressor(), decay=0.9), groups=["m"])
       .fit(df[['index', 'm']], df['yt']))

# %%
plt.figure(figsize=(12, 3))
plt.plot(df['yt'], alpha=0.5);
plt.plot(mod1.predict(df[['m']]), label="grouped")
plt.plot(mod2.predict(df[['index', 'm']]), label="decayed")
plt.legend();
